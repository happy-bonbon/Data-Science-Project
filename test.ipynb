# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('final.csv')
features = dataset[['Maximum temperature (°C)', 'Rainfall (mm)',
                    'Minimum temperature (°C)', 'Evaporation (mm)', 'Sunshine (hours)']]
classlabel = dataset['pricecategory']

features_train, feature_test, class_train, class_test = train_test_split(
    features, classlabel, train_size=0.8, random_state=1)

dt = DecisionTreeClassifier(criterion='entropy', random_state=1)
dt.fit(features_train, class_train)
predictions = dt.predict(feature_test)
print(accuracy_score(class_test, predictions))

fig = plt.figure(figsize=(25, 20))
featurenames = ['Maximum temperature (°C)', 'Rainfall (mm)',
                'Minimum temperature (°C)', 'Evaporation (mm)', 'Sunshine (hours)']
tree.plot_tree(dt, feature_names=featurenames)
# Out:
# 0.3469387755102041
# [Text(0.5493697478991597, 0.9722222222222222, 'Minimum temperature (°C) <= 10.95\nentropy = 1.953\nsamples = 194\nvalue = [51, 53, 29, 61]'),
#  Text(0.3324579831932773, 0.9166666666666666, 'Evaporation (mm) <= 0.7\nentropy = 1.521\nsamples = 101\nvalue = [46, 39, 1, 15]'),
#  Text(0.25840336134453784, 0.8611111111111112, 'Maximum temperature (°C) <= 18.25\nentropy = 0.544\nsamples = 8\nvalue = [7, 0, 1, 0]'),
#  Text(0.2415966386554622, 0.8055555555555556, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]'),
#  Text(0.27521008403361347, 0.8055555555555556, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.4065126050420168, 0.8611111111111112, 'Sunshine (hours) <= 9.05\nentropy = 1.476\nsamples = 93\nvalue = [39, 39, 0, 15]'),
#  Text(0.3088235294117647, 0.8055555555555556, 'Minimum temperature (°C) <= 9.85\nentropy = 1.405\nsamples = 85\nvalue = [38, 37, 0, 10]'),
#  Text(0.21428571428571427, 0.75, 'Rainfall (mm) <= 0.1\nentropy = 1.456\nsamples = 65\nvalue = [31, 24, 0, 10]'),
#  Text(0.14285714285714285, 0.6944444444444444, 'Maximum temperature (°C) <= 18.1\nentropy = 1.141\nsamples = 33\nvalue = [19, 13, 0, 1]'),
#  Text(0.10084033613445378, 0.6388888888888888, 'Minimum temperature (°C) <= 7.05\nentropy = 0.996\nsamples = 28\nvalue = [15, 13, 0, 0]'),
#  Text(0.06722689075630252, 0.5833333333333334, 'Minimum temperature (°C) <= 6.05\nentropy = 0.852\nsamples = 18\nvalue = [13, 5, 0, 0]'),
#  Text(0.05042016806722689, 0.5277777777777778, 'Minimum temperature (°C) <= 3.75\nentropy = 0.98\nsamples = 12\nvalue = [7, 5, 0, 0]'),
#  Text(0.03361344537815126, 0.4722222222222222, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.06722689075630252, 0.4722222222222222, 'Maximum temperature (°C) <= 15.9\nentropy = 0.954\nsamples = 8\nvalue = [3, 5, 0, 0]'),
#  Text(0.05042016806722689, 0.4166666666666667, 'Sunshine (hours) <= 3.65\nentropy = 0.971\nsamples = 5\nvalue = [3, 2, 0, 0]'),
#  Text(0.03361344537815126, 0.3611111111111111, 'Evaporation (mm) <= 3.35\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0, 0]'),
#  Text(0.01680672268907563, 0.3055555555555556, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.05042016806722689, 0.3055555555555556, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.06722689075630252, 0.3611111111111111, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.08403361344537816, 0.4166666666666667, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.08403361344537816, 0.5277777777777778, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]'),
#  Text(0.13445378151260504, 0.5833333333333334, 'Minimum temperature (°C) <= 9.75\nentropy = 0.722\nsamples = 10\nvalue = [2, 8, 0, 0]'),
#  Text(0.11764705882352941, 0.5277777777777778, 'Maximum temperature (°C) <= 13.7\nentropy = 0.503\nsamples = 9\nvalue = [1, 8, 0, 0]'),
#  Text(0.10084033613445378, 0.4722222222222222, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.13445378151260504, 0.4722222222222222, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]'),
#  Text(0.15126050420168066, 0.5277777777777778, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.18487394957983194, 0.6388888888888888, 'Sunshine (hours) <= 5.75\nentropy = 0.722\nsamples = 5\nvalue = [4, 0, 0, 1]'),
#  Text(0.16806722689075632, 0.5833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.20168067226890757, 0.5833333333333334, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.2857142857142857, 0.6944444444444444, 'Minimum temperature (°C) <= 6.55\nentropy = 1.575\nsamples = 32\nvalue = [12, 11, 0, 9]'),
#  Text(0.25210084033613445, 0.6388888888888888, 'Minimum temperature (°C) <= 5.8\nentropy = 0.722\nsamples = 5\nvalue = [1, 4, 0, 0]'),
#  Text(0.23529411764705882, 0.5833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.2689075630252101, 0.5833333333333334, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.31932773109243695, 0.6388888888888888, 'Evaporation (mm) <= 1.4\nentropy = 1.561\nsamples = 27\nvalue = [11, 7, 0, 9]'),
#  Text(0.3025210084033613, 0.5833333333333334, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.33613445378151263, 0.5833333333333334, 'Rainfall (mm) <= 7.0\nentropy = 1.577\nsamples = 24\nvalue = [8, 7, 0, 9]'),
#  Text(0.3025210084033613, 0.5277777777777778, 'Rainfall (mm) <= 3.2\nentropy = 1.509\nsamples = 19\nvalue = [6, 4, 0, 9]'),
#  Text(0.2857142857142857, 0.4722222222222222, 'Maximum temperature (°C) <= 14.45\nentropy = 1.557\nsamples = 14\nvalue = [6, 4, 0, 4]'),
#  Text(0.25210084033613445, 0.4166666666666667, 'Minimum temperature (°C) <= 8.25\nentropy = 0.722\nsamples = 5\nvalue = [4, 0, 0, 1]'),
#  Text(0.23529411764705882, 0.3611111111111111, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.2689075630252101, 0.3611111111111111, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.31932773109243695, 0.4166666666666667, 'Minimum temperature (°C) <= 7.7\nentropy = 1.53\nsamples = 9\nvalue = [2, 4, 0, 3]'),
#  Text(0.3025210084033613, 0.3611111111111111, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.33613445378151263, 0.3611111111111111, 'Rainfall (mm) <= 1.3\nentropy = 0.985\nsamples = 7\nvalue = [0, 4, 0, 3]'),
#  Text(0.31932773109243695, 0.3055555555555556, 'Maximum temperature (°C) <= 15.25\nentropy = 0.971\nsamples = 5\nvalue = [0, 2, 0, 3]'),
#  Text(0.3025210084033613, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.33613445378151263, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.35294117647058826, 0.3055555555555556, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.31932773109243695, 0.4722222222222222, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]'),
#  Text(0.3697478991596639, 0.5277777777777778, 'Rainfall (mm) <= 11.0\nentropy = 0.971\nsamples = 5\nvalue = [2, 3, 0, 0]'),
#  Text(0.35294117647058826, 0.4722222222222222, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.3865546218487395, 0.4722222222222222, 'Rainfall (mm) <= 24.4\nentropy = 0.918\nsamples = 3\nvalue = [2, 1, 0, 0]'),
#  Text(0.3697478991596639, 0.4166666666666667, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]'),
#  Text(0.40336134453781514, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.40336134453781514, 0.75, 'Minimum temperature (°C) <= 9.95\nentropy = 0.934\nsamples = 20\nvalue = [7, 13, 0, 0]'),
#  Text(0.3865546218487395, 0.6944444444444444, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]'),
#  Text(0.42016806722689076, 0.6944444444444444, 'Evaporation (mm) <= 1.7\nentropy = 0.989\nsamples = 16\nvalue = [7, 9, 0, 0]'),
#  Text(0.3865546218487395, 0.6388888888888888, 'Maximum temperature (°C) <= 14.4\nentropy = 0.65\nsamples = 6\nvalue = [1, 5, 0, 0]'),
#  Text(0.3697478991596639, 0.5833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.40336134453781514, 0.5833333333333334, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]'),
#  Text(0.453781512605042, 0.6388888888888888, 'Evaporation (mm) <= 4.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4, 0, 0]'),
#  Text(0.4369747899159664, 0.5833333333333334, 'Evaporation (mm) <= 2.3\nentropy = 0.811\nsamples = 8\nvalue = [6, 2, 0, 0]'),
#  Text(0.42016806722689076, 0.5277777777777778, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.453781512605042, 0.5277777777777778, 'Rainfall (mm) <= 0.1\nentropy = 0.971\nsamples = 5\nvalue = [3, 2, 0, 0]'),
#  Text(0.4369747899159664, 0.4722222222222222, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.47058823529411764, 0.4722222222222222, 'Maximum temperature (°C) <= 14.75\nentropy = 0.811\nsamples = 4\nvalue = [3, 1, 0, 0]'),
#  Text(0.453781512605042, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.48739495798319327, 0.4166666666666667, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]'),
#  Text(0.47058823529411764, 0.5833333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.5042016806722689, 0.8055555555555556, 'Minimum temperature (°C) <= 5.05\nentropy = 1.299\nsamples = 8\nvalue = [1, 2, 0, 5]'),
#  Text(0.47058823529411764, 0.75, 'Minimum temperature (°C) <= 3.3\nentropy = 1.0\nsamples = 2\nvalue = [1, 1, 0, 0]'),
#  Text(0.453781512605042, 0.6944444444444444, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.48739495798319327, 0.6944444444444444, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.5378151260504201, 0.75, 'Sunshine (hours) <= 10.15\nentropy = 0.65\nsamples = 6\nvalue = [0, 1, 0, 5]'),
#  Text(0.5210084033613446, 0.6944444444444444, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.5546218487394958, 0.6944444444444444, 'Maximum temperature (°C) <= 19.45\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 1]'),
#  Text(0.5378151260504201, 0.6388888888888888, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.5714285714285714, 0.6388888888888888, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.7662815126050421, 0.9166666666666666, 'Maximum temperature (°C) <= 17.5\nentropy = 1.662\nsamples = 93\nvalue = [5, 14, 28, 46]'),
#  Text(0.6596638655462185, 0.8611111111111112, 'Evaporation (mm) <= 3.9\nentropy = 1.53\nsamples = 9\nvalue = [4, 2, 0, 3]'),
#  Text(0.6428571428571429, 0.8055555555555556, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]'),
#  Text(0.6764705882352942, 0.8055555555555556, 'Rainfall (mm) <= 0.1\nentropy = 0.971\nsamples = 5\nvalue = [0, 2, 0, 3]'),
#  Text(0.6596638655462185, 0.75, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.6932773109243697, 0.75, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.8728991596638656, 0.8611111111111112, 'Maximum temperature (°C) <= 30.1\nentropy = 1.5\nsamples = 84\nvalue = [1, 12, 28, 43]'),
#  Text(0.7962184873949579, 0.8055555555555556, 'Rainfall (mm) <= 11.6\nentropy = 1.474\nsamples = 72\nvalue = [1, 8, 28, 35]'),
#  Text(0.726890756302521, 0.75, 'Minimum temperature (°C) <= 12.95\nentropy = 1.388\nsamples = 69\nvalue = [0, 8, 26, 35]'),
#  Text(0.6386554621848739, 0.6944444444444444, 'Minimum temperature (°C) <= 11.4\nentropy = 0.986\nsamples = 18\nvalue = [0, 2, 2, 14]'),
#  Text(0.6050420168067226, 0.6388888888888888, 'Evaporation (mm) <= 5.6\nentropy = 0.764\nsamples = 9\nvalue = [0, 0, 2, 7]'),
#  Text(0.5882352941176471, 0.5833333333333334, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]'),
#  Text(0.6218487394957983, 0.5833333333333334, 'Evaporation (mm) <= 5.9\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2]'),
#  Text(0.6050420168067226, 0.5277777777777778, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6386554621848739, 0.5277777777777778, 'Rainfall (mm) <= 1.3\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 1, 2]'),
#  Text(0.6218487394957983, 0.4722222222222222, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.6554621848739496, 0.4722222222222222, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6722689075630253, 0.6388888888888888, 'Minimum temperature (°C) <= 12.1\nentropy = 0.764\nsamples = 9\nvalue = [0, 2, 0, 7]'),
#  Text(0.6554621848739496, 0.5833333333333334, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.6890756302521008, 0.5833333333333334, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7]'),
#  Text(0.8151260504201681, 0.6944444444444444, 'Evaporation (mm) <= 6.3\nentropy = 1.402\nsamples = 51\nvalue = [0, 6, 24, 21]'),
#  Text(0.7563025210084033, 0.6388888888888888, 'Sunshine (hours) <= 8.55\nentropy = 1.468\nsamples = 34\nvalue = [0, 6, 17, 11]'),
#  Text(0.7226890756302521, 0.5833333333333334, 'Rainfall (mm) <= 4.1\nentropy = 1.554\nsamples = 25\nvalue = [0, 6, 9, 10]'),
#  Text(0.7058823529411765, 0.5277777777777778, 'Minimum temperature (°C) <= 16.35\nentropy = 1.491\nsamples = 23\nvalue = [0, 4, 9, 10]'),
#  Text(0.6890756302521008, 0.4722222222222222, 'Rainfall (mm) <= 1.1\nentropy = 1.513\nsamples = 20\nvalue = [0, 4, 9, 7]'),
#  Text(0.6722689075630253, 0.4166666666666667, 'Rainfall (mm) <= 0.1\nentropy = 1.546\nsamples = 16\nvalue = [0, 4, 5, 7]'),
#  Text(0.6554621848739496, 0.3611111111111111, 'Evaporation (mm) <= 3.1\nentropy = 1.577\nsamples = 14\nvalue = [0, 4, 5, 5]'),
#  Text(0.6386554621848739, 0.3055555555555556, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.6722689075630253, 0.3055555555555556, 'Evaporation (mm) <= 3.8\nentropy = 1.555\nsamples = 12\nvalue = [0, 4, 3, 5]'),
#  Text(0.6554621848739496, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.6890756302521008, 0.25, 'Evaporation (mm) <= 5.9\nentropy = 1.485\nsamples = 10\nvalue = [0, 2, 3, 5]'),
#  Text(0.6554621848739496, 0.19444444444444445, 'Sunshine (hours) <= 2.0\nentropy = 1.149\nsamples = 7\nvalue = [0, 1, 1, 5]'),
#  Text(0.6386554621848739, 0.1388888888888889, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6722689075630253, 0.1388888888888889, 'Minimum temperature (°C) <= 14.1\nentropy = 0.65\nsamples = 6\nvalue = [0, 0, 1, 5]'),
#  Text(0.6554621848739496, 0.08333333333333333, 'Maximum temperature (°C) <= 25.45\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.6386554621848739, 0.027777777777777776, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.6722689075630253, 0.027777777777777776, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.6890756302521008, 0.08333333333333333, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.7226890756302521, 0.19444444444444445, 'Sunshine (hours) <= 6.2\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2, 0]'),
#  Text(0.7058823529411765, 0.1388888888888889, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.7394957983193278, 0.1388888888888889, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.6890756302521008, 0.3611111111111111, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.7058823529411765, 0.4166666666666667, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.7226890756302521, 0.4722222222222222, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3]'),
#  Text(0.7394957983193278, 0.5277777777777778, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]'),
#  Text(0.7899159663865546, 0.5833333333333334, 'Maximum temperature (°C) <= 26.1\nentropy = 0.503\nsamples = 9\nvalue = [0, 0, 8, 1]'),
#  Text(0.773109243697479, 0.5277777777777778, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0]'),
#  Text(0.8067226890756303, 0.5277777777777778, 'Sunshine (hours) <= 9.6\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.7899159663865546, 0.4722222222222222, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8235294117647058, 0.4722222222222222, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.8739495798319328, 0.6388888888888888, 'Evaporation (mm) <= 9.2\nentropy = 0.977\nsamples = 17\nvalue = [0, 0, 7, 10]'),
#  Text(0.8571428571428571, 0.5833333333333334, 'Minimum temperature (°C) <= 13.15\nentropy = 0.779\nsamples = 13\nvalue = [0, 0, 3, 10]'),
#  Text(0.8403361344537815, 0.5277777777777778, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8739495798319328, 0.5277777777777778, 'Sunshine (hours) <= 10.45\nentropy = 0.65\nsamples = 12\nvalue = [0, 0, 2, 10]'),
#  Text(0.8571428571428571, 0.4722222222222222, 'Maximum temperature (°C) <= 21.15\nentropy = 0.811\nsamples = 8\nvalue = [0, 0, 2, 6]'),
#  Text(0.8403361344537815, 0.4166666666666667, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.8739495798319328, 0.4166666666666667, 'Minimum temperature (°C) <= 13.75\nentropy = 1.0\nsamples = 4\nvalue = [0, 0, 2, 2]'),
#  Text(0.8571428571428571, 0.3611111111111111, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.8907563025210085, 0.3611111111111111, 'Rainfall (mm) <= 0.8\nentropy = 0.918\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.8739495798319328, 0.3055555555555556, 'Evaporation (mm) <= 6.7\nentropy = 1.0\nsamples = 2\nvalue = [0, 0, 1, 1]'),
#  Text(0.8571428571428571, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8907563025210085, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.907563025210084, 0.3055555555555556, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]'),
#  Text(0.8907563025210085, 0.4722222222222222, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4]'),
#  Text(0.8907563025210085, 0.5833333333333334, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]'),
#  Text(0.865546218487395, 0.75, 'Minimum temperature (°C) <= 17.3\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 2, 0]'),
#  Text(0.8487394957983193, 0.6944444444444444, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.8823529411764706, 0.6944444444444444, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.9495798319327731, 0.8055555555555556, 'Maximum temperature (°C) <= 37.25\nentropy = 0.918\nsamples = 12\nvalue = [0, 4, 0, 8]'),
#  Text(0.9327731092436975, 0.75, 'Maximum temperature (°C) <= 30.8\nentropy = 0.722\nsamples = 10\nvalue = [0, 2, 0, 8]'),
#  Text(0.9159663865546218, 0.6944444444444444, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9495798319327731, 0.6944444444444444, 'Minimum temperature (°C) <= 18.15\nentropy = 0.503\nsamples = 9\nvalue = [0, 1, 0, 8]'),
#  Text(0.9327731092436975, 0.6388888888888888, 'entropy = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7]'),
#  Text(0.9663865546218487, 0.6388888888888888, 'Maximum temperature (°C) <= 34.65\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 1]'),
#  Text(0.9495798319327731, 0.5833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]'),
#  Text(0.9831932773109243, 0.5833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]'),
#  Text(0.9663865546218487, 0.75, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]')]
